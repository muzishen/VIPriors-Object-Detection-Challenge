# %%
import os
try:
    os.chdir("/home/ma-user/work/algo-mmdet2")
except:
    pass
# %run -i 'naie_platform/requirements.py' # run this line to install requirements

# %%
from naie.context import Context
# Context.set("key", "value") 
# %run -i 'mmdet2.py'
